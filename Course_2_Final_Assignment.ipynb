# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Manoj Goyal**

# %% [markdown]
# Data Scientist

# %% [markdown]
# I am interested in data science because with the help of insights from data i can help the business to grow further and as it is a very popular job with great earnings.

# %% [markdown]
# ### Below code prints all elements of a given list ###

# %%
lst=['manoj','goyal','Rahul','Rohan']

for i in lst:
    print(i)
# Out:
# manoj
# goyal
# Rahul
# Rohan

# %% [markdown]
# ## Types of coding languages
#
# * Python
# * R
# * Java
#
# 1. HTML
# 2. CSS
#
# **Link**
#
# <a href="https://en.wikipedia.org/wiki/Programming_language">PROGRAMMING LANGUAGE - WIKIPEDIA</a>
